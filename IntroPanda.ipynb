# %% [markdown]
# <a href="https://colab.research.google.com/github/LisandroZappone/ArquivosDncCurso/blob/main/IntroPanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#instalando pandas
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#importar bibliotecas
import pandas as pd
#sintaxe pandas
#pd.function

# %%
#criando uma series

clientes = ['Lidi','Rodrigo','Jub', 'Carlos'        

]
print(clientes)
type(clientes)

indices = [0,1,2,3]
# Out:
# ['Lidi', 'Rodrigo', 'Jub', 'Carlos']

# %%
#criando serie

serie = pd.Series(data = clientes,
                  index = indices,
                  name = 'Nome dos Clientes'    

)

# %%
serie
# Out:
# 0       Lidi
# 1    Rodrigo
# 2        Jub
# 3     Carlos
# Name: Nome dos Clientes, dtype: object

# %%
#criando DataFrame

df = pd.DataFrame({"nome":['Lidi',
                           'Rodrigo',
                           'Jub',
                           'Carlos'],
                   "idade":[36,38,32,40],
                   "sexo":['feminino','masculino','masculino','masculino'] 
    
})

# %%
df
# Out:
#       nome  idade       sexo
# 0     Lidi     36   feminino
# 1  Rodrigo     38  masculino
# 2      Jub     32  masculino
# 3   Carlos     40  masculino

# %%
df['nome']
# Out:
# 0       Lidi
# 1    Rodrigo
# 2        Jub
# 3     Carlos
# Name: nome, dtype: object

# %%
#lendo dados tabulares

credit = pd.read_csv("/content/credit_card_clients.csv")

# %%
credit
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
#extraindo informações tecnicas de um dataframe

credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
#visualizando as primeiras linhas de um dataframe

credit.head(7)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
# 5   6      50000    1          1         2   37      0      0      0      0
# 6   7     500000    1          1         2   29      0      0      0      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# ...

# %%
#visualizando as últimas linhas de um dataframe

credit.tail(7)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29993  29994     100000    1          1         2   38      0     -1     -1
# 29994  29995      80000    1          2         2   34      2      2      2
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29993      0  ...      70626      69473      55004      2000    111784
# 29994      2  ...      77519      82607      81158      7000      3500
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# ...

# %%
#consultando as dimensões de um dataframe

credit.shape
# Out:
# (30000, 25)

# %%
#renomeando as colunas

credit_renamed = credit.rename(columns = {
    'LIMIT_BAL':'Valor_Credito',
    'SEX':'Sexo',
    'MARRIAGE':'Estado civil',
    'AGE':'Idade',


}    

)

# %%
credit_renamed
# Out:
#           ID  Valor_Credito  Sexo  EDUCATION  Estado civil  Idade  PAY_0  \
# 0          1          20000     2          2             1     24      2
# 1          2         120000     2          2             2     26     -1
# 2          3          90000     2          2             2     34      0
# 3          4          50000     2          2             1     37      0
# 4          5          50000     1          2             1     57     -1
# ...      ...            ...   ...        ...           ...    ...    ...
# 29995  29996         220000     1          3             1     39      0
# 29996  29997         150000     1          3             2     43     -1
# 29997  29998          30000     1          2             2     37      4
# 29998  29999          80000     1          3             1     41      1
# 29999  30000          50000     1          2             1     46      0
#
#        PAY_2  PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# ...

# %%
credit_renamed.drop(['PAY_AMT5'], axis=1,inplace=True)

# %%
#escrevendo dados tabulares
credit_renamed.to_excel('clientes_renamed.xlsx')

# %%
credit = pd.read_excel('/content/clientes_renamed.xlsx')

# %%
credit
# Out:
#        Unnamed: 0     ID  Valor_Credito  Sexo  EDUCATION  Estado civil  Idade  \
# 0               0      1          20000     2          2             1     24
# 1               1      2         120000     2          2             2     26
# 2               2      3          90000     2          2             2     34
# 3               3      4          50000     2          2             1     37
# 4               4      5          50000     1          2             1     57
# ...           ...    ...            ...   ...        ...           ...    ...
# 29995       29995  29996         220000     1          3             1     39
# 29996       29996  29997         150000     1          3             2     43
# 29997       29997  29998          30000     1          2             2     37
# 29998       29998  29999          80000     1          3             1     41
# 29999       29999  30000          50000     1          2             1     46
#
# ...

# %%
#acessando os rótulos das linhas
#index

credit.index
# Out:
# RangeIndex(start=0, stop=30000, step=1)

# %%
#acessando rotulos das colunas

credit.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Valor_Credito', 'Sexo', 'EDUCATION',
#        'Estado civil', 'Idade', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5',
#        'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4',
#        'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3',
#        'PAY_AMT4', 'PAY_AMT6', 'default payment next month'],
#       dtype='object')

# %%
credit.keys()
# Out:
# Index(['Unnamed: 0', 'ID', 'Valor_Credito', 'Sexo', 'EDUCATION',
#        'Estado civil', 'Idade', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5',
#        'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4',
#        'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3',
#        'PAY_AMT4'],
#       dtype='object')

# %%
#identificandoosvalores do dataseta a partir do objeto do tipo array

credit.values
# Out:
# array([[     0,      1,  20000, ...,      0,      0,      1],
#        [     1,      2, 120000, ...,   1000,   2000,      1],
#        [     2,      3,  90000, ...,   1000,   5000,      0],
#        ...,
#        [ 29997,  29998,  30000, ...,   4200,   3100,      1],
#        [ 29998,  29999,  80000, ...,   1926,   1804,      1],
#        [ 29999,  30000,  50000, ...,   1000,   1000,      1]])

# %%
credit.to_numpy()
# Out:
# array([[     0,      1,  20000, ...,      0,      0,      1],
#        [     1,      2, 120000, ...,   1000,   2000,      1],
#        [     2,      3,  90000, ...,   1000,   5000,      0],
#        ...,
#        [ 29997,  29998,  30000, ...,   4200,   3100,      1],
#        [ 29998,  29999,  80000, ...,   1926,   1804,      1],
#        [ 29999,  30000,  50000, ...,   1000,   1000,      1]])

# %%
#identificando os tipos de dados que contem cada coluna

credit.dtypes
# Out:
# Unnamed: 0                    int64
# ID                            int64
# Valor_Credito                 int64
# Sexo                          int64
# EDUCATION                     int64
# Estado civil                  int64
# Idade                         int64
# PAY_0                         int64
# PAY_2                         int64
# PAY_3                         int64
# PAY_4                         int64
# PAY_5                         int64
# PAY_6                         int64
# BILL_AMT1                     int64
# BILL_AMT2                     int64
# BILL_AMT3                     int64
# BILL_AMT4                     int64
# BILL_AMT5                     int64
# BILL_AMT6                     int64
# PAY_AMT1                      int64
# PAY_AMT2                      int64
# PAY_AMT3                      int64
# PAY_AMT4                      int64
# PAY_AMT6                      int64
# default payment next month    int64
# dtype: object

# %%
#iterando linhas e colunas de um dataframe

for index, row in credit.iterrows():
  print(index, row)
# Out:
# 0 Unnamed: 0                        0
# ID                                1
# Valor_Credito                 20000
# Sexo                              2
# EDUCATION                         2
# Estado civil                      1
# Idade                            24
# PAY_0                             2
# PAY_2                             2
# PAY_3                            -1
# PAY_4                            -1
# PAY_5                            -2
# PAY_6                            -2
# BILL_AMT1                      3913
# BILL_AMT2                      3102
# BILL_AMT3                       689
# BILL_AMT4                         0
# BILL_AMT5                         0
# BILL_AMT6                         0
# PAY_AMT1                          0
# PAY_AMT2                        689
# PAY_AMT3                          0
# PAY_AMT4                          0
# PAY_AMT6                          0
# default payment next month        1
# Name: 0, dtype: int64

# %%
credit = pd.read_excel("/content/clientes_renamed.xlsx")

# %%
credit
# Out:
#        Unnamed: 0     ID  Valor_Credito  Sexo  EDUCATION  Estado civil  Idade  \
# 0               0      1          20000     2          2             1     24
# 1               1      2         120000     2          2             2     26
# 2               2      3          90000     2          2             2     34
# 3               3      4          50000     2          2             1     37
# 4               4      5          50000     1          2             1     57
# ...           ...    ...            ...   ...        ...           ...    ...
# 29995       29995  29996         220000     1          3             1     39
# 29996       29996  29997         150000     1          3             2     43
# 29997       29997  29998          30000     1          2             2     37
# 29998       29998  29999          80000     1          3             1     41
# 29999       29999  30000          50000     1          2             1     46
#
# ...

# %%
#acessando colunas

credit["Sexo"]
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        1
#         ..
# 29995    1
# 29996    1
# 29997    1
# 29998    1
# 29999    1
# Name: Sexo, Length: 30000, dtype: int64

# %%
#acessando MULTIPLAS colunas

credit[['ID','Sexo','Idade']]
# Out:
#           ID  Sexo  Idade
# 0          1     2     24
# 1          2     2     26
# 2          3     2     34
# 3          4     2     37
# 4          5     1     57
# ...      ...   ...    ...
# 29995  29996     1     39
# 29996  29997     1     43
# 29997  29998     1     37
# 29998  29999     1     41
# 29999  30000     1     46
#
# [30000 rows x 3 columns]
# ...

# %%
#filtrando colunas

credit.filter(like='PAY'
    

)
# Out:
#        PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0          2      2     -1     -1     -2     -2         0       689         0
# 1         -1      2      0      0      0      2         0      1000      1000
# 2          0      0      0      0      0      0      1518      1500      1000
# 3          0      0      0      0      0      0      2000      2019      1200
# 4         -1      0     -1      0      0      0      2000     36681     10000
# ...      ...    ...    ...    ...    ...    ...       ...       ...       ...
# 29995      0      0      0      0      0      0      8500     20000      5003
# 29996     -1     -1     -1     -1      0      0      1837      3526      8998
# 29997      4      3      2     -1      0      0         0         0     22000
# 29998      1     -1      0      0      0     -1     85900      3409      1178
# 29999      0      0      0      0      0      0      2078      1800      1430
#
#        PAY_AMT4  PAY_AMT6
# ...

# %%
#acessando uma linha

credit.loc[99]
# Out:
# Unnamed: 0                       99
# ID                              100
# Valor_Credito                 20000
# Sexo                              1
# EDUCATION                         2
# Estado civil                      1
# Idade                            38
# PAY_0                             0
# PAY_2                             0
# PAY_3                             0
# PAY_4                             0
# PAY_5                             0
# PAY_6                            -1
# BILL_AMT1                     17973
# BILL_AMT2                     19367
# BILL_AMT3                     19559
# BILL_AMT4                     18240
# BILL_AMT5                     17928
# BILL_AMT6                       150
# PAY_AMT1                       1699
# PAY_AMT2                       1460
# PAY_AMT3                        626
# PAY_AMT4                       1750
# PAY_AMT6                          0
# default payment next month        1
# Name: 99, dtype: int64

# %%
#acessando MULTIPLAS linhas

credit.loc[0:4]
# Out:
#    Unnamed: 0  ID  Valor_Credito  Sexo  EDUCATION  Estado civil  Idade  PAY_0  \
# 0           0   1          20000     2          2             1     24      2
# 1           1   2         120000     2          2             2     26     -1
# 2           2   3          90000     2          2             2     34      0
# 3           3   4          50000     2          2             1     37      0
# 4           4   5          50000     1          2             1     57     -1
#
#    PAY_2  PAY_3  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0      2     -1  ...        689          0          0          0         0
# 1      2      0  ...       2682       3272       3455       3261         0
# 2      0      0  ...      13559      14331      14948      15549      1518
# 3      0      0  ...      49291      28314      28959      29547      2000
# 4      0     -1  ...      35835      20940      19146      19131      2000
#
# ...

# %%
#acessando linhas e colunas

credit.loc[0:4,['ID','Sexo']]
# Out:
#    ID  Sexo
# 0   1     2
# 1   2     2
# 2   3     2
# 3   4     2
# 4   5     1

# %%
#usando iloc

credit.iloc[0:4,2:8]
# Out:
#    Valor_Credito  Sexo  EDUCATION  Estado civil  Idade  PAY_0
# 0          20000     2          2             1     24      2
# 1         120000     2          2             2     26     -1
# 2          90000     2          2             2     34      0
# 3          50000     2          2             1     37      0

# %%
#acessar linhas atraves de mascaras booleanas

credit[credit['Idade'] == 30]
# Out:
#        Unnamed: 0     ID  Valor_Credito  Sexo  EDUCATION  Estado civil  Idade  \
# 13             13     14          70000     1          2             2     30
# 27             27     28          50000     2          3             2     30
# 35             35     36         160000     1          1             2     30
# 44             44     45          40000     2          1             2     30
# 67             67     68         210000     2          1             2     30
# ...           ...    ...            ...   ...        ...           ...    ...
# 29953       29953  29954         170000     1          1             2     30
# 29954       29954  29955         180000     1          2             2     30
# 29956       29956  29957         150000     1          1             2     30
# 29962       29962  29963          50000     1          2             2     30
# 29985       29985  29986         240000     1          1             2     30
#
# ...

# %%
#lendo dados tabulares

credit = pd.read_csv('/content/credit_card_clients_2.csv')

credit
# Out:
#           ID  LIMIT_BAL      SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  \
# 0          1    20000.0      2.0        2.0       1.0  24.0    2.0    2.0
# 1          2   120000.0      2.0        2.0       2.0  26.0   -1.0    2.0
# 2          3    90000.0      2.0        2.0       2.0  34.0    0.0    0.0
# 3          4    50000.0      2.0        2.0       1.0  37.0    0.0    0.0
# 4          5    50000.0      1.0        2.0       1.0  57.0   -1.0    0.0
# ...      ...        ...      ...        ...       ...   ...    ...    ...
# 30012  30013        NaN      NaN        NaN       NaN   NaN    NaN    NaN
# 30013  30014        NaN      NaN        NaN       NaN   NaN    NaN    NaN
# 30014  30015        NaN      NaN        NaN       NaN   NaN    NaN    NaN
# 30015  30016        NaN      NaN        NaN       NaN   NaN    NaN    NaN
# 30016  30017    30018.0  29999.0    30000.0    5000.0   0.0    1.0    2.0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
#extraindo o sumário das estatísticas descritivas

credit.describe()
# Out:
#                  ID       LIMIT_BAL          SEX     EDUCATION      MARRIAGE  \
# count  30017.000000    30003.000000  30003.00000  30003.000000  30003.000000
# mean   15009.000000   167471.486118      2.60354      2.852948      1.718461
# std     8665.305851   129747.540674    173.18208    173.187526     28.861831
# min        1.000000    10000.000000      1.00000      0.000000      0.000000
# 25%     7505.000000    50000.000000      1.00000      1.000000      1.000000
# 50%    15009.000000   140000.000000      2.00000      2.000000      2.000000
# 75%    22513.000000   240000.000000      2.00000      2.000000      2.000000
# max    30017.000000  1000000.000000  29999.00000  30000.000000   5000.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30003.000000  30003.000000  30003.000000  30003.000000  30003.000000
# mean      35.484252     -0.016665     -0.133687     -0.166150     -0.219111
# ...

# %%
#extraindo somente uma coluna

credit['EDUCATION'].describe()
# Out:
# count    30003.000000
# mean         2.852948
# std        173.187526
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max      30000.000000
# Name: EDUCATION, dtype: float64

# %%
#media(ponto de equilibrio da distribuição)

credit['LIMIT_BAL'].mean()
# Out:
# 167471.48611805486

# %%
#moda(valores que ocorrem com mais frequencia)

credit['LIMIT_BAL'].mode()
# Out:
# 0    50000.0
# dtype: float64

# %%
#mediana(ponto que divide a distribuição emm partes iguais(equiprováveis))

credit['LIMIT_BAL'].median()
# Out:
# 140000.0

# %%
#variância(media dos desvios quadraticos da V.A, em relação ea média)

credit['LIMIT_BAL'].var()
# Out:
# 16834424311.013964

# %%
#desvio padrão(raiz quadrada da variância)

credit['LIMIT_BAL'].std()
# Out:
# 129747.54067424154
